# %% [markdown]
# # Author: Mohamed Malhan .s
#
# # GRIP @ The Sparks Foundation , Data Science n Business Analytics Internship.
#
#
# # Task 3 Exploratory Data Analysis (EDA)  of given store DATA SET.

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from plotnine import *
#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read the data set using pandas

# %%
store_data= pd.read_csv(r'C:\Users\mohamed malhan\Desktop\ml\SampleSuperstore.csv')
store_data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store_data=store_data.rename(columns={'Sub-Category':'Scategory'})
store_data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category  Scategory     Sales  Quantity  \
# 0        42420  South        Furniture  Bookcases  261.9600         2
# 1        42420  South        Furniture     Chairs  731.9400         3
# 2        90036   West  Office Supplies     Labels   14.6200         2
# 3        33311  South        Furniture     Tables  957.5775         5
# 4        33311  South  Office Supplies    Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
store_data.describe()
#it shows the statestical details about the data set
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
store_data.info()
#we can get the following infos about the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ship Mode    9994 non-null   object
#  1   Segment      9994 non-null   object
#  2   Country      9994 non-null   object
#  3   City         9994 non-null   object
#  4   State        9994 non-null   object
#  5   Postal Code  9994 non-null   int64
#  6   Region       9994 non-null   object
#  7   Category     9994 non-null   object
#  8   Scategory    9994 non-null   object
#  9   Sales        9994 non-null   float64
#  10  Quantity     9994 non-null   int64
#  11  Discount     9994 non-null   float64
#  12  Profit       9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
store_data.shape
# it has 13 columns and 9994 rows of data
# Out:
# (9994, 13)

# %% [markdown]
#  There are no null values

# %%
store_data.duplicated().sum()
# the duplicate data are found
# Out:
# 17

# %%
store_data.drop(store_data.duplicated().sum())
store_data.shape
# removing those duplicate data
# Out:
# (9994, 13)

# %% [markdown]
# # Droping irrelevent columns

# %%
store_data= store_data.drop(columns=['Postal Code'])
store_data.head()
#here postal cosde is not needed so it is removed
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#   Region         Category  Scategory     Sales  Quantity  Discount    Profit
# 0  South        Furniture  Bookcases  261.9600         2      0.00   41.9136
# 1  South        Furniture     Chairs  731.9400         3      0.00  219.5820
# 2   West  Office Supplies     Labels   14.6200         2      0.00    6.8714
# 3  South        Furniture     Tables  957.5775         5      0.45 -383.0310
# 4  South  Office Supplies    Storage   22.3680         2      0.20    2.5164

# %% [markdown]
# # checking statistical relation between rows and columns

# %%
store_data.describe(include=["object", "bool"])
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
#
#        Region         Category Scategory
# count    9994             9994      9994
# unique      4                3        17
# top      West  Office Supplies   Binders
# freq     3203             6026      1523

# %%
# we can observe that the data arrangement is so dissimilar 
store_data.hist(figsize=(8, 10), bins=25, xlabelsize=9, ylabelsize=15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000176F3FA1F88>,
# ...
#       dtype=object)

# %% [markdown]
# # Pie Charts that represents the counts of various fields

# %%
#count (ie) no.of times that perticular category has been repeated
plt.figure(figsize =(6,6))
textprops ={'fontsize':15}
plt.title('Category')
plt.pie(store_data['Category'].value_counts(),labels=store_data.Category.value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()
#by this we could conclude that office supplies have purchased by a large no. of audience

# %%
#we could see the contribution of each SUB-CATEGORIES
plt.figure(figsize =(6,6))
textprops ={'fontsize':15}
plt.title('Scategory')
plt.pie(store_data['Scategory'].value_counts(),labels=store_data.Scategory.value_counts().index,autopct='%1.1f%%',textprops = textprops)
plt.show()

# %%
#based on region , west region is the most dominating over other regions
plt.figure(figsize=(6,6))
plt.title('Region')
plt.pie(store_data.Region.value_counts(),labels=store_data.Region.value_counts().index , autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Heat Map

# %%
#heat map using co-relation
store_data.corr()
plt.figure(figsize=(10,5))
sns.heatmap(store_data.corr(), annot= True, cmap='RdBu')
plt.show()
#By this we could visualize the dependency of each field with one another

# %% [markdown]
# # To Derive a relation between Categories and their Profit

# %%
#Relation between DISCOUNT N CATEGORY
carrier_count = store_data['Category'].value_counts()
sns.set(style="darkgrid")
sns.barplot(store_data.Category, store_data.Discount, alpha=0.9)
plt.title('Frequency Distribution of supplies')
plt.ylabel('Discount', fontsize=12)
plt.xlabel('Category', fontsize=12)
plt.show()
#FURNITURES has the overall highest discount

# %%
#Relation between SUB-CATEGORY N DISCOUNT
carrier_count = store_data['Scategory'].value_counts()
sns.set(style="whitegrid")
sns.barplot(store_data.Discount, store_data.Scategory, alpha=0.9)
plt.title('Frequency Distribution of supplies')
plt.ylabel('Sub-Category', fontsize=12 )
plt.xlabel('Discount', fontsize=12)
plt.show()
#BINDERS have highest discount and COPIERS have moderate discount
##even the overall discount is greater for furnituers , the highest discout for subcategories is from office supplies n 
##technology

# %%
#Relation beteween SUB-CATEGORIES AND SALES
carrier_count = store_data['Scategory'].value_counts()
sns.set(style="whitegrid")
sns.barplot(store_data.Sales, store_data.Scategory, alpha=0.9)
plt.title('Frequency Distribution of supplies')
plt.ylabel('Sub-Category', fontsize=12 )
plt.xlabel('Sales', fontsize=12)
plt.show()
#  The sales for machines n copiers is very high so even if we reduce the dicount for those products it won't affect us

# %%
#Relation between states and the sales 
top_States_s = store_data.groupby('State').Sales.sum()

#plotting to see it visually
plt.style.use ('seaborn')
top_States_s .plot(kind='bar', figsize=(10,5),fontsize=14)
plt.xlabel('States',fontsize=15)
plt.ylabel('Total Sale',fontsize=15)
plt.title('Top 10 states Sales vs Profit',fontsize =15)
plt.show()
 #highest sales is at california , new york , texas , washington,etc..

# %%
#Relation between states and discout
top_States_s = store_data.groupby('State').Discount.sum()

#plotting to see it visually
plt.style.use ('seaborn')
top_States_s .plot(kind='bar', figsize=(10,5),fontsize=14)
#top_States_p.plot(kind='bar', figsize=(10,5),fontsize=14,color='red')
plt.xlabel('States',fontsize=15)
plt.ylabel('Total Discount',fontsize=15)
plt.title('Top 10 states Sales vs Profit',fontsize =15)
plt.show()

# %%
#Relation between CATEGORY N PROFIT
carrier_count = store_data['Category'].value_counts()
sns.set(style="whitegrid")
sns.barplot(store_data.Profit, store_data.Category, alpha=0.9)
plt.title('Frequency Distribution of supplies')
plt.ylabel('Category', fontsize=12 )
plt.xlabel('Profit', fontsize=12)
plt.show()
#those COPIERS belongs tho TECHNOLOGY cartegory which gives highest profit

# %%
# A more detailed view ( subcategory vs profit)
plt.figure(figsize=(14,12))
statewise=store_data.groupby(['Scategory'])['Profit'].sum().nlargest(50)
statewise.plot.barh()  #for horizontal
#it is much better if the store concenterates more on technology side as it yields more profit compared to others
# Out:
# <AxesSubplot:ylabel='Scategory'>

# %%
# Profit trend based on the increase in Discount
plt.figure(figsize=(8,7))
sns.lineplot(store_data['Discount'],store_data['Profit'],data=store_data)
#When there is a great rise in the discount the profit rate decreases drastically

# %% [markdown]
# # Categories Based On Sales and Profit

# %%
#computing top categories in terms of sales from first 200 observations 
top_category_s = store_data.groupby('Category').Sales.sum().nlargest(n=200)
#computing top categories in terms of profit from1st 200 observations
top_category_p = store_data.groupby('Category').Profit.sum().nlargest(n=200)


#plotting to see it visually
plt.style.use ('seaborn')
top_category_s.plot(kind='bar', figsize=(10,5),fontsize=14)
top_category_p.plot(kind='bar', figsize=(10,5),fontsize=14,color='red')
plt.xlabel('Category',fontsize=15)
plt.ylabel('Total Sale',fontsize=15)
plt.title('Top Category Sales vs Profit',fontsize =15)
plt.show()

#Shows both profit and sales of all three categories
#dispite of the low sale of office supplies it has considerably higher profit

# %% [markdown]
# # Sub-Categories Based on Sales and Profit

# %%
#computing top Sub-categories in terms of sales from first 200 observations 
top_category_s = store_data.groupby('Scategory').Sales.sum().nlargest(n=200)
#computing top Sub-categories in terms of profit from1st 200 observations
top_category_p = store_data.groupby('Scategory').Profit.sum().nlargest(n=200)


#plotting to see it visually
plt.style.use ('seaborn')
top_category_s.plot(kind='bar', figsize=(10,5),fontsize=14)
top_category_p.plot(kind='bar', figsize=(10,5),fontsize=14,color='red')
plt.xlabel('Sub-category',fontsize=15)
plt.ylabel('Total Sale',fontsize=15)
plt.title('Top Sub-Category Sales vs Profit',fontsize =15)
plt.show()

#copiers , phones and accesseries have the highest sale as well as profit

# %% [markdown]
# # Visualising the Sales vs Profits in different States

# %%
#computing top States in terms of sales from first 10 observations 
top_States_s = store_data.groupby('State').Sales.sum().nlargest(n=10)
#computing top States in terms of profit from1st 200 observations
top_States_p= store_data.groupby('State').Profit.sum().nlargest(n=10)   


#plotting to see it visually
plt.style.use ('seaborn')
top_States_s .plot(kind='bar', figsize=(10,5),fontsize=14)
top_States_p.plot(kind='bar', figsize=(10,5),fontsize=14,color='red')
plt.xlabel('States',fontsize=15)
plt.ylabel('Total Sale',fontsize=15)
plt.title('Top 10 states Sales vs Profit',fontsize =15)
plt.show()

# %% [markdown]
# # Products that the most profiting States buy

# %%
def state_data_viewer(states):
    product_data = store_data.groupby(['State'])
    for state in states:
        data=product_data.get_group(state).groupby(['Category'])
        fig,ax = plt.subplots(1,3,figsize=(20,5))
        fig.suptitle(state,fontsize=20)
        ax_index =0
        for cat in ['Furniture','Office Supplies','Technology']:
            cat_data =data.get_group(cat).groupby(['Scategory']).sum()
            sns.barplot(x=cat_data.Profit, y= cat_data.index, ax=ax[ax_index])
            ax[ax_index].set_ylabel(cat)
            ax_index +=1 
        fig.show()

# %%
States =['California', 'Washington','Mississippi','Arizona','Texas']
state_data_viewer(States)
#we could observe the most profitting product for the following states

# %% [markdown]
# # Sales in different segments

# %%
#we can see which segment of people buy which categorty of products 
flip_xlabels = theme(axis_text_x=element_text(angle=90, hjust=1),figure_size=(10,5),axis_ticks_length_major=10,
                     axis_ticks_length_minor=5)
(ggplot(store_data,aes(x='Scategory',fill='Sales'))+geom_bar()+facet_wrap(['Segment'])+flip_xlabels
 +theme(axis_text_x = element_text(size=12))+ggtitle('Sales'))
#it is obvious that consumers contribute for greater sale.
# Out:
# <ggplot: (-9223371900314784860)>

# %% [markdown]
# # CONCLUTION
# # 1] Since the sale for "machines" and "copiers" are considerably high , the discount offered for it can be further reduced , which will eventually lead to higher profit.
# # 2] Discount offered for tables can be increased as it's sale is very low , which ends up in loss for the store.
# # 3] increasing the sales of furnitures , esspecially for tables in the states like "Washington" , "Mississipi" , etc.. where , the sales of tables is higher, by which thw loss rate could be reduced.
# # 4] The sales can be targeted for "consumers" . since , they buy a lots of products than other Segment of people . This could lead for better profit.
# # 5]The sale and profit in california is much higher than any other states , so it would be much better in terms of profit if more preriority is given for that state.
